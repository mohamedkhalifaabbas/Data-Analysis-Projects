# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/heart-failure-prediction/heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.sample(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 703   41   F           ATA        126          306          0     Normal
# 377   65   M           ASY        160            0          1         ST
# 622   59   M           ASY        110          239          0        LVH
# 762   40   M           ASY        110          167          0        LVH
# 459   41   M           ASY        104            0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 703    163              N      0.0       Up             0
# 377    122              N      1.2     Flat             1
# 622    142              Y      1.2     Flat             1
# 762    114              Y      2.0     Flat             1
# 459    111              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df['Age'].describe()
# Out:
# count    918.000000
# mean      53.510893
# std        9.432617
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    725
# F    193
# Name: count, dtype: int64

# %%
plt.bar(df['Sex'].unique() ,df['Sex'].value_counts() , width = .2)
plt.show()

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
plt.pie(  list(df['ChestPainType'].value_counts())  ,  autopct="%.2f%%")
plt.show()

# %%
df['RestingBP'].describe()
# Out:
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64

# %%
df['Cholesterol'].describe()
# Out:
# count    918.000000
# mean     198.799564
# std      109.384145
# min        0.000000
# 25%      173.250000
# 50%      223.000000
# 75%      267.000000
# max      603.000000
# Name: Cholesterol, dtype: float64

# %%
df['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
plt.pie(df['FastingBS'].value_counts() , labels=['normal blood sugar' , 'unnormal blood sugar'] ,  autopct="%.2f%%")
plt.show()

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df['RestingECG'].describe()
# Out:
# count        918
# unique         3
# top       Normal
# freq         552
# Name: RestingECG, dtype: object

# %%
df['MaxHR'].describe()
# Out:
# count    918.000000
# mean     136.809368
# std       25.460334
# min       60.000000
# 25%      120.000000
# 50%      138.000000
# 75%      156.000000
# max      202.000000
# Name: MaxHR, dtype: float64

# %%
df['MaxHR'].sample(5)
# Out:
# 751    172
# 760     95
# 858    160
# 602     98
# 192    160
# Name: MaxHR, dtype: int64

# %%
df['Oldpeak'].describe()
# Out:
# count    918.000000
# mean       0.887364
# std        1.066570
# min       -2.600000
# 25%        0.000000
# 50%        0.600000
# 75%        1.500000
# max        6.200000
# Name: Oldpeak, dtype: float64

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.groupby(['Sex'])['Age'].agg(['min' , 'max'])
# Out:
#      min  max
# Sex
# F     30   76
# M     28   77

# %%
df[df['Sex'] == 'M'].Age.mean()
# Out:
# 53.78206896551724

# %%
df[df['Sex'] == 'F'].Age.mean()
# Out:
# 52.49222797927461

# %%
df.groupby(['ChestPainType'])['Age'].agg(['mean' , 'max' , 'min'])
# Out:
#                     mean  max  min
# ChestPainType
# ASY            54.959677   77   31
# ATA            49.242775   74   28
# NAP            53.310345   76   33
# TA             54.826087   74   30

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df[df['Age'] == df['Age'].min()][['Age' , 'Sex' , 'RestingBP']]
# Out:
#      Age Sex  RestingBP
# 208   28   M        130

# %%
df.nlargest(2 , 'Age')[['Age' , 'Sex', 'RestingBP']]
# Out:
#      Age Sex  RestingBP
# 447   77   M        124
# 814   77   M        125

# %%
df[df['Age'] > 50]['RestingBP'].mean().round()
# Out:
# 135.0

# %%
df[df['Age'] < 40]['RestingBP'].mean().round()
# Out:
# 124.0

# %%
df.loc[[df['Age'].idxmin() ,df['Age'].idxmax() ], ['Age' ,'Cholesterol']]
# Out:
#      Age  Cholesterol
# 208   28          132
# 447   77          171

# %%
df[df['Age'] > 45]['Cholesterol'].mean().round()
# Out:
# 195.0

# %%
df.groupby('FastingBS')['Age'].mean()
# Out:
# FastingBS
# 0    52.481534
# 1    56.897196
# Name: Age, dtype: float64

# %%
df.loc[(df["FastingBS"] == 1) & (df['Age'] < 35), ['Age' , 'Sex', 'FastingBS']]
# Out:
#      Age Sex  FastingBS
# 294   32   M          1
# 313   34   M          1

# %%
df.loc[(df["FastingBS"] == 0) & (df['Age'] > 60), 'FastingBS'].count()
# Out:
# 148

# %%
df.groupby('RestingECG')['Age'].agg(['mean' , 'min' , 'max' , 'std' , 'count'])
# Out:
#                  mean  min  max       std  count
# RestingECG
# LVH         56.218085   28   77  8.855965    188
# Normal      51.740942   29   75  9.360491    552
# ST          56.140449   30   77  8.990732    178

# %%
plt.bar(df['RestingECG'].unique() ,df['RestingECG'].value_counts())
plt.show()

# %%
plt.bar(df['RestingECG'].unique() ,df.groupby('RestingECG')['Age'].mean().round())
plt.show()

# %%
plt.scatter(df['RestingECG'].unique() ,df.groupby('RestingECG')['Age'].max().round())
plt.show()

# %%
df.loc[df['Age'] < 40]['MaxHR'].mean()
# Out:
# 157.1625

# %%
df.loc[df['Age'] > 60]['MaxHR'].mean()
# Out:
# 124.94570135746606

# %%
df.loc[(df['MaxHR'] >= 200) |(df['MaxHR'] <= 60) ]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 390   51   M           ASY        140            0          0     Normal
# 829   29   M           ATA        130          204          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 390     60              N      0.0     Flat             1
# 829    202              N      0.0       Up             0

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
df[df['ExerciseAngina'] == 'N']['Age'].mean().round()
# Out:
# 52.0

# %%
df[df['ExerciseAngina'] == 'Y']['Age'].mean().round()
# Out:
# 56.0

# %%
dex = df[df['ExerciseAngina'] == 'Y']
plt.pie(df[(df['Age'] > 50)]['ExerciseAngina'].value_counts() ,labels=['N' , 'Y'] , autopct='%.f%%' , explode=[0 , .01])
plt.show()

# %%
df[df['Age'] > 40 ]['Oldpeak'].mean()
# Out:
# 0.9376969696969696

# %%
df[df['Age'] < 40 ]['Oldpeak'].mean()
# Out:
# 0.4325

# %%
df.nlargest(3 ,  'Oldpeak')[['Age' , 'Oldpeak']]
# Out:
#      Age  Oldpeak
# 850   62      6.2
# 771   55      5.6
# 166   50      5.0

# %%
df.nsmallest(3 , 'Oldpeak')[['Age' , 'Oldpeak']]
# Out:
#      Age  Oldpeak
# 324   46     -2.6
# 413   56     -2.0
# 325   42     -1.5

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
df.groupby('ST_Slope')['Age'].agg(['mean' , 'min' , 'max' , 'std' , 'count']).T
# Out:
# ST_Slope       Down        Flat          Up
# mean      58.317460   55.256522   50.711392
# min       37.000000   31.000000   28.000000
# max       76.000000   76.000000   77.000000
# std        8.517203    8.682456    9.629837
# count     63.000000  460.000000  395.000000

# %%
df.groupby('HeartDisease')['Age'].agg(['mean' , 'min' , 'max'  , 'count'])
# Out:
#                    mean  min  max  count
# HeartDisease
# 0             50.551220   28   76    410
# 1             55.899606   31   77    508

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
pd.crosstab(df['Sex'] , df['ChestPainType'])
# Out:
# ChestPainType  ASY  ATA  NAP  TA
# Sex
# F               70   60   53  10
# M              426  113  150  36

# %%
df.groupby('Sex')['RestingBP'].agg(['mean' , 'max' , 'min'])
# Out:
#            mean  max  min
# Sex
# F    132.212435  200   94
# M    132.445517  200    0

# %%
df.groupby('Sex')['Cholesterol'].agg(['mean' , 'max' , 'min'])
# Out:
#            mean  max  min
# Sex
# F    241.196891  564    0
# M    187.513103  603    0

# %%
 pd.crosstab(df['Sex'] , df['FastingBS']).T
# Out:
# Sex          F    M
# FastingBS
# 0          167  537
# 1           26  188

# %%
cross_result = pd.crosstab(df['Sex'] , df['RestingECG']).T
cross_result
# Out:
# Sex           F    M
# RestingECG
# LVH          47  141
# Normal      118  434
# ST           28  150

# %%
cross_result.plot(kind = 'bar' )
plt.title("Resting electrocardiogram")
plt.ylabel("No.")
plt.xlabel("RestingECG Types")
plt.show()

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %%
df.groupby('Sex')["MaxHR" ].agg(['mean' , 'max' , 'min'])
# Out:
#            mean  max  min
# Sex
# F    146.139896  192   90
# M    134.325517  202   60

# %%
pd.crosstab([df['Sex'] ,df['RestingECG'] ] ,df["ChestPainType"] )
# Out:
# ChestPainType   ASY  ATA  NAP  TA
# Sex RestingECG
# F   LVH          22    9   15   1
#     Normal       38   42   31   7
#     ST           10    9    7   2
# M   LVH          80   14   32  15
#     Normal      246   81   92  15
#     ST          100   18   26   6
